# %% [markdown]
# ## 1. Setting Kaggle's Datasets API
#
# This is our first notebook. So first, let's get a Kaggle API key, and create  easy access to download Kaggle's datasets.
# More details on Kaggle's API can be found in the following [link](https://github.com/Kaggle/kaggle-api#api-credentials). Moreover, a quick explanation on how to get an API key and use it can be found in the following [link](https://gist.github.com/jayspeidell/d10b84b8d3da52df723beacc5b15cb27)

# %%
# !mkdir /root/.kaggle/
# Out:
# mkdir: cannot create directory ‘/root/.kaggle/’: File exists

# %%
import json
import os

# Installing the Kaggle package
# !pip install kaggle 


# creating kaggle.json file with the personal API-Key details 
# You can also put this file on your Google Drive
with open('/root/.kaggle/kaggle.json', 'w') as file:
  json.dump(api_token, file)
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2022.9.24)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %% [markdown]
# Let's check if we can use Kaggle API and download the [US Baby Names  dataset](https://www.kaggle.com/kaggle/us-baby-names)

# %%
# searching for the dataset
# !kaggle datasets list -s baby
# Out:
# ref                                           title                              size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------  --------------------------------  -----  -------------------  -------------  ---------  ---------------
# kaggle/us-baby-names                          US Baby Names                     173MB  2017-11-21 22:18:15          30674        323  0.5882353
# thedevastator/us-baby-names-by-year-of-birth  Baby Names by Year                  9MB  2022-09-20 06:26:33            752         35  1.0
# ironicninja/baby-names                        Baby Names                          5MB  2021-02-09 16:21:40            455         12  0.88235295
# haezer/french-baby-names                      French Baby Names                  18MB  2020-04-07 16:32:38            429         15  0.88235295
# robikscube/us-baby-name-popularity            US Baby Name Popularity            52MB  2022-08-11 02:17:35            159         18  1.0
# roopalik/amazon-baby-dataset                  Amazon baby dataset                18MB  2017-02-01 21:01:16            989         17  0.5294118
# new-york-city/nyc-baby-names                  NYC Baby Names                    136KB  2017-09-08 20:04:20            728         11  0.7058824
# mahmoudreda55/amazon-baby-product-data        Amazon Baby product data           30MB  2022-10-20 16:32:43             67         11  0.875
# fanbyprinciple/indian-male-baby-names         Indian Male baby names             69KB  2021-06-19 04:45:32             95          8  1.0
# rahulsarkar221/nyc-popular-baby-names         Nyc popular baby names            316KB  2022-06-20 17:21:08             38          8  1.0
# samrat77/baby-names-dataset                   Baby Names DataSet                 85KB  2019-03-21 06:21:34            573         11  0.5882353
# darinhawley/us-top-1000-baby-names-18802020   US Top 1000 Baby Names 1880-2020    2MB  2021-10-27 19:10:27            319         19  0.88235295
# ytmytm/babyfeeds                              Baby girl breast feeds             41KB  2019-07-14 18:31:46            129          6  0.9411765
# programmerrdai/popular-baby-names             Popular Baby Names                 37MB  2022-08-10 00:20:53             25          9  0.7647059
# zerryberry/us-baby-names                      US baby names                       7MB  2020-09-22 00:48:56             80          4  0.875
# jaidevchittoria/babies-products-and-toys      Baby_products_and_toys             11MB  2020-10-25 09:36:12             78          7  0.6875
# prashant111/most-popular-baby-names-in-nyc    Most Popular Baby Names in NYC     86KB  2020-03-15 07:26:17            119         12  0.5294118
# new-york-city/nyc-most-popular-baby-names     NYC Most Popular Baby Names       176KB  2021-01-01 19:58:02            638         14  0.7941176
# des137/us-births-2018                         US births (2018)                  120MB  2019-11-28 09:26:32           2186         46  0.88235295
# cocowaffle/baby-photos                        Baby Photos                       115KB  2017-04-11 18:18:23            472          3  0.75

# %%
# Creating a dataset directory
# !mkdir ./datasets
# !mkdir ./datasets/us-baby-name

# download the dataset from Kaggle and unzip it
# !kaggle datasets download kaggle/us-baby-names -f database.sqlite -p ./datasets/us-baby-name/database.sqlite
# !chdir ./datasets/us-baby-name/database.sqlite/
# !unzip ./datasets/us-baby-name/database.sqlite/*.zip  -d ./datasets/us-baby-name/database.sqlite
# Out:
# Downloading database.sqlite.zip to ./datasets/us-baby-name/database.sqlite
#  88% 116M/131M [00:00<00:00, 214MB/s]
# 100% 131M/131M [00:00<00:00, 226MB/s]
# /bin/bash: chdir: command not found
# Archive:  ./datasets/us-baby-name/database.sqlite/database.sqlite.zip
#   inflating: ./datasets/us-baby-name/database.sqlite/database.sqlite

# %% [markdown]
# ## 2. Working with SQLite

# %% [markdown]
# In the first part, we downloaded an SQLite database into Colab. Let's connect to the dataset using the [sqlite3 package](https://docs.python.org/2/library/sqlite3.html): First, let's import the required packages, and answer several questions about the data.

# %%
import sqlite3
import matplotlib
import matplotlib.pyplot as plt
import os
# %matplotlib inline

DB_PATH = './datasets/us-baby-name/database.sqlite'

# %% [markdown]
# **Question 1: How many names in the dataset?**

# %%
conn = sqlite3.connect(f'{DB_PATH}/database.sqlite') # connecting to the database
c = conn.cursor() # creating a cursor object
print("The number of national names in the dataset: %s" % c.execute("SELECT count(*) FROM NationalNames" ).fetchone()) # execute a query & fetch the results
print("The number of state names in the dataset: %s" % c.execute("SELECT count(*) FROM StateNames" ).fetchone()) 
c.close() # close the cursor
# Out:
# The number of national names in the dataset: 1825433
# The number of state names in the dataset: 5647426

# %% [markdown]
# **Question 2: How many distinct names in the Washington State? and in New York State?**

# %%
c = conn.cursor()
print(c.execute("SELECT COUNT(DISTINCT(Name)) as count FROM StateNames WHERE State='NY' " ).fetchone()[0])
c.close()
# Out:
# 13933

# %% [markdown]
# **Question 3: What are the most rare names?**

# %%
c = conn.cursor()  
rows = c.execute("""SELECT Name, Sum(Count) as TotalNumberOfBabies
             FROM NationalNames
             Group By Name
             Order by Sum(Count)""" ) 
i = 1 
for r in rows:
  if i > 20:
    break
  print(f"{i}. {r[0]}, {r[1]}")
  #print({0}, {1}, {2}.format(i, r[0], r[1]))
  i += 1
c.close() # close the cursor
# Out:
# 1. Aabid, 5
# 2. Aadhyan, 5
# 3. Aadian, 5
# 4. Aadrian, 5
# 5. Aadrit, 5
# 6. Aafreen, 5
# 7. Aagot, 5
# 8. Aahron, 5
# 9. Aaiyana, 5
# 10. Aaja, 5
# 11. Aakanksha, 5
# 12. Aakira, 5
# 13. Aakiyah, 5
# 14. Aaleeya, 5
# 15. Aalias, 5
# 16. Aalicia, 5
# 17. Aaliyaa, 5
# 18. Aallyah, 5
# 19. Aalon, 5
# 20. Aalyia, 5

# %% [markdown]
# Now let's print the names in descending order:
#
# **Question 4: What are the most common names?**

# %%
c = conn.cursor()  
rows = c.execute("""SELECT Name, Sum(Count) as TotalNumberOfBabies
             FROM NationalNames
             Group By Name
             Order by Sum(Count) DESC""" )

 
i = 1 
for r in rows:
  if i > 20:
    break
  print(f"{i}. {r[0]}, {r[1]}")
  #print({0}, {1}, {2}.format(i, r[0], r[1]))
  i += 1
c.close() # close the cursor
# Out:
# 1. James, 5129096
# 2. John, 5106590
# 3. Robert, 4816785
# 4. Michael, 4330805
# 5. Mary, 4130441
# 6. William, 4071368
# 7. David, 3590557
# 8. Joseph, 2580687
# 9. Richard, 2564867
# 10. Charles, 2376700
# 11. Thomas, 2291517
# 12. Christopher, 2004177
# 13. Daniel, 1876880
# 14. Elizabeth, 1606282
# 15. Patricia, 1575529
# 16. Matthew, 1558671
# 17. Jennifer, 1467573
# 18. George, 1464430
# 19. Linda, 1454599
# 20. Barbara, 1437083

# %% [markdown]
# **Question 5:** Write a code that queries the babies DB you prepared and retrieves the number of male babies named George in 1992.

# %%
c = conn.cursor()
print(c.execute("SELECT COUNT FROM NationalNames WHERE Name=\"George\" and Year=1992 and Gender=\"M\"").fetchone()[0])
c.close()
# Out:
# 3892

# %% [markdown]
# ***Question 6:*** Write a function that returns how many babies were born in a given state in a given year.
# Use it to calculate the number of babies born in TX in 1986.

# %%
def get_count(country,year):
  c = conn.cursor()
  return_value= c.execute("SELECT SUM(Count) from StateNames WHERE State=? and Year=?",(country,year)).fetchone()[0]
  c.close()
  return return_value

print(get_count("TX",'1986'))
# Out:
# 277779

# %% [markdown]
# **Question 7:** Write a function that returns how many male babies named Robert where born in a given state in a given year.
# Use it to find the state in which the highest number of babies Robert were born in 2010 (10pt)

# %%
def get_count(name,year):
  c = conn.cursor()
  return_value =  c.execute("SELECT max(count),State FROM (SELECT sum(Count) as count,State FROM StateNames WHERE (Name=? AND Year=?) Group By State)",(name,year)).fetchone()[1]
  return return_value

print(get_count("Robert",2010))
# Out:
# CA

# %% [markdown]
# ## 3. Working with Pony ORM

# %%
# !pip install pony
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pony in /usr/local/lib/python3.7/dist-packages (0.7.16)

# %%
# !kaggle datasets list -s pokemon
# Out:
# ref                                                 title                                         size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------  -------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# abcsds/pokemon                                      Pokemon with stats                            15KB  2016-08-29 06:01:43          93876       2276  0.88235295
# vishalsubbiah/pokemon-images-and-types              Pokemon Image Dataset                          2MB  2018-12-17 01:01:39          19849        431  0.9411765
# rounakbanik/pokemon                                 The Complete Pokemon Dataset                  47KB  2017-09-29 19:49:32          47442        985  0.8235294
# kvpratama/pokemon-images-dataset                    Pokemon Images Dataset                        71MB  2020-08-10 02:05:00          11573        254  0.875
# terminus7/pokemon-challenge                         Pokemon- Weedle's Cave                       285KB  2017-09-21 08:43:04          37281        428  0.7352941
# lantian773030/pokemonclassification                 7,000 Labeled Pokemon                        417MB  2019-11-09 23:15:13           4237        140  0.875
# mlomuscio/pokemon                                   Pokemon                                       14KB  2019-09-03 01:14:49           1187         19  0.8235294
# thedagger/pokemon-generation-one                    Pokemon Generation One                         2GB  2018-08-02 06:47:33           6404        241  0.625
# mariotormo/complete-pokemon-dataset-updated-090420  Complete Pokemon Dataset (Updated 16.04.21)  195KB  2021-04-16 06:32:50           6418        148  0.9705882
# maca11/all-pokemon-dataset                          All Pokemon Dataset                           56KB  2021-10-20 07:04:01           1134         52  0.88235295
# mrdew25/pokemon-database                            Pokemon Database                              82KB  2021-05-16 00:32:47           1384         35  0.8235294
# lunamcbride24/pokemon-type-matchup-data             Pokemon Type Matchup Data                      9KB  2020-10-14 18:56:23           1505         69  1.0
# mylesoneill/pokemon-sun-and-moon-gen-7-stats        Pokemon Sun and Moon (Gen 7) Stats           271KB  2019-11-17 22:16:07           3010         79  0.9705882
# abcsds/pokemongo                                    PokemonGO                                      4KB  2016-08-26 04:57:19           2446         31  0.8235294
# brilja/pokemon-mugshots-from-super-mystery-dungeon  Pokemon Mugshots                              81MB  2019-05-21 04:09:03            388         26  0.5625
# hamdallak/the-world-of-pokemons                     The World of Pokemons                         18KB  2021-09-29 11:41:27           1087         83  0.7058824
# aaronyin/oneshotpokemon                             One-Shot-Pokemon Images                        2GB  2018-05-29 05:32:03           1481         91  0.75
# hasanarcas/pokemon-stats-dataset                    Pokemon Stats Dataset                         47KB  2022-08-20 19:19:48            409         31  0.9705882
# shubhamchambhare/pokemons-and-there-stats           Pokemons and their stats                      28KB  2021-06-05 20:43:31           1728         63  0.85294116
# hlrhegemony/pokemon-image-dataset                   Complete Pokemon Image Dataset                58MB  2020-11-15 01:51:47            867         38  0.875

# %%
# !kaggle datasets download abcsds/pokemon -p ./datasets/
# !unzip ./datasets/pokemon.zip -d ./datasets/pokemon/
# Out:
# Downloading pokemon.zip to ./datasets
#   0% 0.00/14.9k [00:00<?, ?B/s]
# 100% 14.9k/14.9k [00:00<00:00, 906kB/s]
# Archive:  ./datasets/pokemon.zip
#   inflating: ./datasets/pokemon/Pokemon.csv

# %%
# !ls ./datasets/pokemon
# Out:
# Pokemon.csv

# %% [markdown]
# ### 3.1 Creating DB using Objects

# %% [markdown]
# Now let's use the Pokemon dataset and Pony to create a database. The first step is to create classes that will map to tables in the generate database:

# %%
from pony.orm import *
# Creating a new database
db = Database()
db.bind(provider='sqlite', filename='/content/datasets/pokemon/pokemon.pony.db', create_db=True) # notice we can easily use other type of databases instead of SQLite

# Each class will be map to a table
class Trainer(db.Entity):
    name = Required(str)
    age = Required(int)
    pokemons_list = Set('Pokemon') # Connected to the Pokemon class
    
class Pokemon(db.Entity):
    name = Required(str) # cannot be None
    age  = Optional(int)
    attack_power = Required(int)
    defense_power = Required(int)
    trainer = Optional(Trainer) # Connected to the Trainer class

# %%
show(Trainer)
# Out:
# class Trainer(Entity):
#     id = PrimaryKey(int, auto=True)
#     name = Required(str)
#     age = Required(int)
#     pokemons_list = Set(Pokemon)

# %%
set_sql_debug(True) # helps to see what SQL commands are running
db.generate_mapping(create_tables=True) # create tables

# %% [markdown]
# We can see that Pony create the Pokemon & the Trainer tables in the database. Next, we will use the Pandas package to insert data into these tables:

# %%
import pandas as pd 
df = pd.read_csv('./datasets/pokemon/Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# Let's iterate on the dataframe rows and create a Pokemon object from each row:

# %%
import random

for idx, row in df.iterrows():
    Pokemon(name=row['Name'],
            age=random.randint(0,500),
            attack_power=row['Sp. Atk'], 
            defense_power=row['Sp. Def'])

# %% [markdown]
# We have created 800 objects, one for each row. However, none of them was committed to the DB yet. Let's commit!

# %%
commit()

# %% [markdown]
# Now let's add Ash as a trainer object, and add two pokemons trained by Ash:

# %%
ash_trainer = Trainer(name='Ash Ketchum', age=10)
pikachu = Pokemon(name='pikachu',age=6,attack_power=50, defense_power=50, trainer=ash_trainer)
charmander =  Pokemon(name='charmander',age=2,attack_power=60, defense_power=50,trainer=ash_trainer)
commit()

# %% [markdown]
# We can now easily retrieve data using objects:

# %%
pikachu.trainer.age
# Out:
# 10

# %%
list(pikachu.trainer.pokemons_list)
# Out:
# [Pokemon[801], Pokemon[802]]

# %%
list(pikachu.trainer.pokemons_list)[1].name
# Out:
# 'charmander'

# %% [markdown]
# We can also simply update the database using the created objects:

# %%
pikachu.age
# Out:
# 6

# %%
pikachu.age = 110
commit()

# %%
pikachu.age
# Out:
# 110

# %% [markdown]
# ### 3.2 Creating  Objects from DB:

# %%
# !pip install pony
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pony in /usr/local/lib/python3.7/dist-packages (0.7.16)

# %% [markdown]
# Using Pony, we can also connect to existing database, and easily search it without even knowing SQL. First, let's connect between Pony to an existing database:

# %%
# !pip install pony
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pony in /usr/local/lib/python3.7/dist-packages (0.7.16)

# %%
from pony.orm import *
db = Database()
db.bind(provider='sqlite', filename='/content/datasets/pokemon/pokemon.pony.db') # notice we don't use create_db=True here

class Trainer(db.Entity):
    name = Required(str)
    age = Required(int)
    pokemons_list = Set('Pokemon')
    
class Pokemon(db.Entity):
    name = Required(str) # cannot be None
    age  = Optional(int)
    attack_power = Required(int)
    defense_power = Required(int)
    trainer = Optional(Trainer)
db.generate_mapping()
set_sql_debug(True)

# %% [markdown]
# **Question 1:** Print the names of Pokemons which their attack is higher than 100 and their defence is higher than attack.

# %%
[i.name for i in select(p for p in Pokemon if p.attack_power >100 and p.defense_power > p.attack_power )]
# Out:
# ['Ho-oh',
#  'MetagrossMega Metagross',
#  'Latias',
#  'LatiasMega Latias',
#  'RotomHeat Rotom',
#  'RotomWash Rotom',
#  'RotomFrost Rotom',
#  'RotomFan Rotom',
#  'RotomMow Rotom',
#  'Florges',
#  'Sylveon',
#  'Goodra']

# %% [markdown]
# We can observe that behind the scenes Pony translate the query into a SQL query and returned a list with the names of the matched pokemons.

# %% [markdown]
# **Question 2:** retrieve all the pokemon names that their attack is between 50 to 100.

# %%
[i.name for i in select(p for p in Pokemon if p.attack_power >50 and p.attack_power <100 )]
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Charmander',
#  'Charmeleon',
#  'Wartortle',
#  'Blastoise',
#  'Butterfree',
#  'Pidgeot',
#  'Fearow',
#  'Arbok',
#  'Raichu',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Ninetales',
#  'Wigglytuff',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Parasect',
#  'Venomoth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Primeape',
#  'Growlithe',
#  'Poliwrath',
#  'Machamp',
#  'Bellsprout',
#  'Weepinbell',
#  'Tentacruel',
#  'Golem',
#  'Ponyta',
#  'Rapidash',
#  'Magnemite',
#  "Farfetch'd",
#  'Dodrio',
#  'Dewgong',
#  'Muk',
#  'Cloyster',
#  'Hypno',
#  'Voltorb',
#  'Electrode',
#  'Exeggcute',
#  'Lickitung',
#  'Koffing',
#  'Weezing',
#  'KangaskhanMega Kangaskhan',
#  'Horsea',
#  'Seadra',
#  'Seaking',
#  'Staryu',
#  'Scyther',
#  'Electabuzz',
#  'Pinsir',
#  'PinsirMega Pinsir',
#  'Gyarados',
#  'GyaradosMega Gyarados',
#  'Lapras',
#  'Flareon',
#  'Porygon',
#  'Omanyte',
#  'Kabuto',
#  'Kabutops',
#  'Aerodactyl',
#  'AerodactylMega Aerodactyl',
#  'Snorlax',
#  'Articuno',
#  'Dragonair',
#  'Bayleef',
#  'Meganium',
#  'Cyndaquil',
#  'Quilava',
#  'Croconaw',
#  'Feraligatr',
#  'Noctowl',
#  'Ledian',
#  'Ariados',
#  'Crobat',
#  'Chinchou',
#  'Lanturn',
#  'Togetic',
#  'Natu',
#  'Xatu',
#  'Mareep',
#  'Flaaffy',
#  'Bellossom',
#  'Azumarill',
#  'Politoed',
#  'Jumpluff',
#  'Yanma',
#  'Quagsire',
#  'Umbreon',
#  'Murkrow',
#  'Misdreavus',
#  'Unown',
#  'Girafarig',
#  'Forretress',
#  'Dunsparce',
#  'Steelix',
#  'SteelixMega Steelix',
#  'Granbull',
#  'Qwilfish',
#  'Scizor',
#  'ScizorMega Scizor',
#  'Ursaring',
#  'Slugma',
#  'Magcargo',
#  'Piloswine',
#  'Corsola',
#  'Remoraid',
#  'Delibird',
#  'Mantine',
#  'Houndour',
#  'Kingdra',
#  'Donphan',
#  'Stantler',
#  'Smoochum',
#  'Elekid',
#  'Magby',
#  'Blissey',
#  'Entei',
#  'Suicune',
#  'Pupitar',
#  'Tyranitar',
#  'TyranitarMega Tyranitar',
#  'Lugia',
#  'Treecko',
#  'Grovyle',
#  'Torchic',
#  'Combusken',
#  'Marshtomp',
#  'Swampert',
#  'SwampertMega Swampert',
#  'Mightyena',
#  'Lombre',
#  'Ludicolo',
#  'Nuzleaf',
#  'Shiftry',
#  'Wingull',
#  'Pelipper',
#  'Kirlia',
#  'Masquerain',
#  'Breloom',
#  'Vigoroth',
#  'Slaking',
#  'Whismur',
#  'Loudred',
#  'Exploud',
#  'Delcatty',
#  'Sableye',
#  'SableyeMega Sableye',
#  'Mawile',
#  'MawileMega Mawile',
#  'Aggron',
#  'AggronMega Aggron',
#  'Medicham',
#  'MedichamMega Medicham',
#  'Electrike',
#  'Plusle',
#  'Minun',
#  'Illumise',
#  'Swalot',
#  'Carvanha',
#  'Sharpedo',
#  'Wailmer',
#  'Wailord',
#  'Numel',
#  'Torkoal',
#  'Spoink',
#  'Grumpig',
#  'Spinda',
#  'Flygon',
#  'Cacnea',
#  'Altaria',
#  'Zangoose',
#  'Lunatone',
#  'Solrock',
#  'Whiscash',
#  'Crawdaunt',
#  'Claydol',
#  'Lileep',
#  'Cradily',
#  'Armaldo',
#  'Castform',
#  'Kecleon',
#  'Shuppet',
#  'Banette',
#  'BanetteMega Banette',
#  'Dusclops',
#  'Tropius',
#  'Chimecho',
#  'Absol',
#  'Glalie',
#  'Spheal',
#  'Sealeo',
#  'Walrein',
#  'Clamperl',
#  'Huntail',
#  'Shelgon',
#  'Metang',
#  'Metagross',
#  'Registeel',
#  'DeoxysDefense Forme',
#  'DeoxysSpeed Forme',
#  'Grotle',
#  'Torterra',
#  'Chimchar',
#  'Monferno',
#  'Piplup',
#  'Prinplup',
#  'Bibarel',
#  'Kricketune',
#  'Luxio',
#  'Luxray',
#  'Rampardos',
#  'WormadamPlant Cloak',
#  'WormadamSandy Cloak',
#  'WormadamTrash Cloak',
#  'Mothim',
#  'Vespiquen',
#  'Buizel',
#  'Floatzel',
#  'Cherubi',
#  'Cherrim',
#  'Shellos',
#  'Gastrodon',
#  'Ambipom',
#  'Drifloon',
#  'Drifblim',
#  'Lopunny',
#  'LopunnyMega Lopunny',
#  'Purugly',
#  'Chingling',
#  'Skuntank',
#  'Bronzong',
#  'Mime Jr.',
#  'Chatot',
#  'Spiritomb',
#  'Garchomp',
#  'Hippowdon',
#  'Drapion',
#  'Croagunk',
#  'Toxicroak',
#  'Carnivine',
#  'Lumineon',
#  'Mantyke',
#  'Snover',
#  'Abomasnow',
#  'Lickilicky',
#  'Rhyperior',
#  'Electivire',
#  'Leafeon',
#  'Mamoswine',
#  'Gallade',
#  'GalladeMega Gallade',
#  'Probopass',
#  'Dusknoir',
#  'Froslass',
#  'Rotom',
#  'Uxie',
#  'Regigigas',
#  'Cresselia',
#  'Phione',
#  'Servine',
#  'Serperior',
#  'Pignite',
#  'Oshawott',
#  'Dewott',
#  'Watchog',
#  'Liepard',
#  'Pansage',
#  'Simisage',
#  'Pansear',
#  'Simisear',
#  'Panpour',
#  'Simipour',
#  'Munna',
#  'Unfezant',
#  'Zebstrika',
#  'Gigalith',
#  'Woobat',
#  'Swoobat',
#  'Audino',
#  'AudinoMega Audino',
#  'Conkeldurr',
#  'Palpitoad',
#  'Seismitoad',
#  'Leavanny',
#  'Scolipede',
#  'Whimsicott',
#  'Petilil',
#  'Basculin',
#  'Krookodile',
#  'Crustle',
#  'Yamask',
#  'Cofagrigus',
#  'Tirtouga',
#  'Carracosta',
#  'Archen',
#  'Garbodor',
#  'Zorua',
#  'Cinccino',
#  'Gothita',
#  'Gothorita',
#  'Gothitelle',
#  'Swanna',
#  'Vanillite',
#  'Vanillish',
#  'Sawsbuck',
#  'Emolga',
#  'Escavalier',
#  'Foongus',
#  'Amoonguss',
#  'Frillish',
#  'Jellicent',
#  'Joltik',
#  'Galvantula',
#  'Ferrothorn',
#  'Klang',
#  'Klinklang',
#  'Eelektrik',
#  'Elgyem',
#  'Litwick',
#  'Lampent',
#  'Haxorus',
#  'Cubchoo',
#  'Beartic',
#  'Cryogonal',
#  'Stunfisk',
#  'Mienfoo',
#  'Mienshao',
#  'Druddigon',
#  'Golurk',
#  'Bisharp',
#  'Braviary',
#  'Mandibuzz',
#  'Zweilous',
#  'Cobalion',
#  'Terrakion',
#  'Virizion',
#  'MeloettaPirouette Forme',
#  'Quilladin',
#  'Chesnaught',
#  'Fennekin',
#  'Braixen',
#  'Froakie',
#  'Frogadier',
#  'Fletchinder',
#  'Talonflame',
#  'Vivillon',
#  'Litleo',
#  'Flabébé',
#  'Floette',
#  'Skiddo',
#  'Gogoat',
#  'Pangoro',
#  'Furfrou',
#  'Espurr',
#  'MeowsticMale',
#  'MeowsticFemale',
#  'Spritzee',
#  'Aromatisse',
#  'Swirlix',
#  'Slurpuff',
#  'Malamar',
#  'Barbaracle',
#  'Skrelp',
#  'Dragalge',
#  'Clauncher',
#  'Helioptile',
#  'Tyrantrum',
#  'Amaura',
#  'Aurorus',
#  'Hawlucha',
#  'Dedenne',
#  'Goomy',
#  'Sliggoo',
#  'Klefki',
#  'Trevenant',
#  'GourgeistAverage Size',
#  'GourgeistSmall Size',
#  'GourgeistLarge Size',
#  'GourgeistSuper Size',
#  'Noivern',
#  'Zygarde50% Forme',
#  'charmander']

# %% [markdown]
# **Question 3**: find the pokemon with the highest attack power:

# %%
needed_power=max([i.attack_power for i in select(p for p in Pokemon)])
[i.name for i in select(p for p in Pokemon if p.attack_power ==needed_power )]
# Out:
# ['MewtwoMega Mewtwo Y']

# %% [markdown]
# Using the [Kickstarter Projects Dataset](https://www.kaggle.com/kemical/kickstarter-projects#ks-projects-201801.csv), answer the following questions:

# %% [markdown]
# **Question 1**: Load the dataset to SQLite DB using PonyORM.

# %%
# !wget https://github.com/maniknarang/kickstarter-data-analysis/raw/master/ks-projects-201801.csv
# Out:
# --2022-11-07 13:30:00--  https://github.com/maniknarang/kickstarter-data-analysis/raw/master/ks-projects-201801.csv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/maniknarang/kickstarter-data-analysis/master/ks-projects-201801.csv [following]
# --2022-11-07 13:30:00--  https://raw.githubusercontent.com/maniknarang/kickstarter-data-analysis/master/ks-projects-201801.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58030359 (55M) [text/plain]
# Saving to: ‘ks-projects-201801.csv.1’
#
# ks-projects-201801. 100%[===================>]  55.34M   149MB/s    in 0.4s
#
# 2022-11-07 13:30:01 (149 MB/s) - ‘ks-projects-201801.csv.1’ saved [58030359/58030359]

# %%
import pandas as pd 

df = pd.read_csv("ks-projects-201801.csv",encoding="utf-8")
df
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# 0                Poetry    Publishing      GBP  2015-10-09   1000.0
# 1        Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2        Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3                 Music         Music      USD  2012-04-16   5000.0
# 4          Film & Video  Film & Video      USD  2015-08-29  19500.0
# ...                 ...           ...      ...         ...      ...
# 378656      Documentary  Film & Video      USD  2014-10-17  50000.0
# 378657   Narrative Film  Film & Video      USD  2011-07-19   1500.0
# 378658   Narrative Film  Film & Video      USD  2010-08-16  15000.0
# 378659       Technology    Technology      USD  2016-02-13  15000.0
# 378660  Performance Art           Art      USD  2011-08-16   2000.0
#
#                    launched  pledged     state  backers country  usd pledged  \
# 0       2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1       2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2       2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3       2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4       2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
# ...                     ...      ...       ...      ...     ...          ...
# 378656  2014-09-17 02:35:30     25.0  canceled        1      US         25.0
# 378657  2011-06-22 03:35:14    155.0    failed        5      US        155.0
# 378658  2010-07-01 19:40:30     20.0    failed        1      US         20.0
# 378659  2016-01-13 18:13:53    200.0    failed        6      US        200.0
# 378660  2011-07-19 09:07:47    524.0    failed       17      US        524.0
#
#         usd_pledged_real  usd_goal_real
# 0                    0.0        1533.95
# 1                 2421.0       30000.00
# 2                  220.0       45000.00
# 3                    1.0        5000.00
# 4                 1283.0       19500.00
# ...                  ...            ...
# 378656              25.0       50000.00
# 378657             155.0        1500.00
# 378658              20.0       15000.00
# 378659             200.0       15000.00
# 378660             524.0        2000.00
#
# [378661 rows x 15 columns]

# %% [markdown]
# **Question 1:** Use Pony for creating a new database.
#
# The database should include a Project table with a name, category and country as strings, whreas pledged and goal as floats.
# Fill the table using the CSV file.

# %%
from pyparsing.helpers import string
from pony.orm import *
import random
# Creating a new database
db = Database()
db.bind(provider='sqlite', filename='/content/datasets/project.pony.db', create_db=True) # notice we can easily use other type of databases instead of SQLite

class Project(db.Entity):
    name = Required(str)
    category = Required(str)
    country = Required(str)
    pledged = Required(float)
    goal = Required(float)


set_sql_debug(True)
db.generate_mapping(create_tables=True)

for idx, row in df.iterrows():
    Project(name=str(row['name']),category=row['category'],
            country=row['country'], 
            pledged=row['pledged'],
            goal=row['goal'])

commit()

# %% [markdown]
# **Question 2**: Write a Pony code which retrieve the project's names of those which their contry is "US".

# %%
[i.name for i in select(p for p in Project if p.country =="US")]
# Out:
# ['Greeting From Earth: ZGAC Arts Capsule For ET',
#  'Where is Hank?',
#  'ToshiCapital Rekordz Needs Help to Complete Album',
#  'Community Film Project: The Art of Neighborhood Filmmaking',
#  'Monarch Espresso Bar',
#  'Support Solar Roasted Coffee & Green Energy!  SolarCoffee.co',
#  'Chaser Strips. Our Strips make Shots their B*tch!',
#  'SPIN - Premium Retractable In-Ear Headphones with Mic',
#  'STUDIO IN THE SKY - A Documentary Feature Film (Canceled)',
#  'Lisa Lim New CD!',
#  'The Cottage Market',
#  'G-Spot Place for Gamers to connect with eachother & go pro!',
#  'Survival Rings',
#  'The Beard',
#  'Notes From London: Above & Below',
#  "Mike Corey's Darkness & Light Album",
#  'Boco Tea',
#  'CMUK. Shoes: Take on Life Feet First.',
#  'Alice in Wonderland in G Minor',
#  'The Book Zoo - A Mini-Comic',
#  'Matt Cavenaugh & Jenny Powers make their 1st album!',
#  'My Moon - Animated Short Film',
#  'Ledr workbook: one tough journal!',
#  'BB130A',
#  'Chris Eger Band - New Nashville Record!',
#  'Squatch Watchers',
#  'Arrows & Sound Debut Album',
#  'Zen in America: a film on Zen Buddhism in North America',
#  'Galaxy: Winnie and Friends',
#  'Help Scott Reynolds Make a New Record!',
#  'Phil Younger - Slow Down (Official Music Video)',
#  '"THE RETURN" book project',
#  'Penny Bingo Playing Card Game fun for the whole family!',
#  'The Please, Please Me: Studio Premiere',
#  'WE ARE ONE: STREET MUSIC OF NEW ORLEANS',
#  'Hot Chicken Takes Over.',
#  'Star and the Snowman',
#  'Seas of Iron',
#  '(In)visible Empire Tees',
#  "I'LL SEE YOU IN MY DREAMS - narrative feature film",
#  'H2O The Underwater Portraits',
#  'SkateFrames-Photo frame made from recycled skateboard wood',
#  "A Teacher's Travels in China",
#  'Mothers Into Living Fit Yoga DVD for Moms and Babies',
#  'Mobile barbecue & catering trailer',
#  'Following the Call - A Novel',
#  'UNDERWATER',
#  'The Fanalyzers: Views from the Stands',
#  'Empires at Sea',
#  'Teachers In The Sky',
#  'TO RUSSIA WITH LOVE AND SIMON',
#  'HIIT Bottle™',
#  '"JurassicJurassix" by The Guilt',
#  'Pantochino Productions: "Cinderella Skeleton, the Musical"',
#  'Gizbee™ Unlimited Removable Storage for Your Travel Photos',
#  'Diposta - liberating people from their postal mailbox.',
#  'My Future Just Passed - Debut CD - Jazz Trio',
#  'Loot and Recruit - A quirky, combative, deck building game',
#  "Babe Ruth's Family Kitchen - Gourmet Hot Dogs and Condiments",
#  '"It\'s Complicated" by Ariana Salome',
#  'Secular Solstice 2014',
#  'Uncommon Rhythm - Season One',
#  'Legacy of Svarog | a Unique 3D Action RPG and Adventure Game',
#  'AWE - Antediluvian Wars: Extermination Tactical Card Game',
#  'Road to the Shire',
#  'Spiral Electric Skylab Recording',
#  'The Locals Only Shirt',
#  'The Onrust Project and Two Row Treaty of 1613',
#  'My Coffee Box',
#  '¿Tu Sabes? (You Know?) a music collaboration by Daya & Edu',
#  'P/O/V Comic and Literary Anthology',
#  '"Little Shop of Horrors" at the Browncoat Theatre!',
#  'Glyscian Debut Album Recording (Canceled)',
#  'The Dark Waters Project',
#  'Los Angeles International Student Film Festival',
#  'Bob Contemplates Ending It All',
#  'The Girls Bathroom',
#  'New Lasagna',
#  'Just Another Reality Show: Season 3',
#  'Backroads EP Processing Costs',
#  'Disaster Area: A Podcast',
#  'Titanium EDC Bottle Opener',
#  '"Eat Like A Gilmore" Cookbook',
#  'Bad Example (A Southern Trailer Park Fairy Tale) Indie Short',
#  'PATTY AT THE PARTY - a mumblecore horror feature',
#  'Bold Threadz',
#  'Happy Fix USA',
#  'Be part of the next SMB Project album',
#  'DAYTRADER - A Financial Board Game',
#  'iRNinja - Control your TV with a simple press of a button',
#  "Mama's Meatballs",
#  'Ebony Child:Music Artist drops New Album, Comic Book, & Film',
#  'Alpha Omega E.P.',
#  'Carriage',
#  'AllThis TV',
#  'The Legendary YD 2016 Tour',
#  'MEMORY LANE',
#  'Jane Brown... a story of courage, survival and love',
#  'CASE:Lynk - Your EMERGENCY iPhone Charge & Sync Cord',
#  'Cat - Pre-Professional Ballerina',
#  'Wordwright: re·de·fin·ing word play',
#  "SERiNO'S PiZZA ROLLiNG PiZZA LAB (Food Truck)",
#  'A photobook of life in Japan',
#  'Operation: Make Stuff',
#  'Xi3: Help us Usher in the Post-PC Era',
#  'help our wood shop buy a lathe & hopefully a laser engraver',
#  'Store Facades - Paintings out of Pittsburgh',
#  'Brandi Emma promotes her new, 5-song EP because of YOU!  Pre-Order Right Here :)',
#  'URBNPOP / CHRIS HAMER SKETCHBOOK',
#  'Sellegg start up classified site',
#  "Farmer Brown's Analogy Farm Game for ages three and above",
#  'The Seven Rays',
#  'Four Short Stories and Ten Love Poems',
#  'David LaRocca: Star Spawn',
#  'Calendars for Cats',
#  '#NotMyPresident Protest Tees',
#  'Musical Light Suit',
#  'Gone In 61 Seconds',
#  'HYDRA DICE',
#  'Hangar 1 Foundation',
#  "Adele's Heart is Going to Edinburgh",
#  "ODIN: Android 'Smart' Projector to Carry in Your Pocket",
#  '42 Sketches 2013',
#  'ADVENT SAGA, DIGITAL TACTICAL CARD GAME',
#  "One Man's Opinion Of Moonlight Song Collection",
#  'Crap Amidst Hilarity, vol. 1',
#  'Packable, Fashionable & Protective; the ULTIMATE sun hat.',
#  'Echo-Fuel: Make Echo Portable with Universal Charging Base!',
#  'New world disorder',
#  '"GENERATION FX" a documentary film.',
#  'Help me prepare for an upcoming art show',
#  'COVENANT',
#  'Elephant Gun Media Blitzkrieg',
#  'Our Shared Stories: An Afghan Diary',
#  'The Gentle Art Of Tutelage',
#  'Air Bonsai | Create your "little star"',
#  'Canadian Invasion\'s "Choose Your Own Adventure" Album',
#  'Wrist Covers',
#  'High Stakes: A Short Film',
#  'Fomatek: Foam Laptop Desks & Music Stands Elevate your Gear.',
#  'Sky Scrapers Project',
#  "Keys to the Moon's First Full Length Album!",
#  'KILOS.',
#  'Strait Jacket – Tangle Prevention For Headphones',
#  'Airfoil Click Pen: Aviation Inspired, for gel & rollerball',
#  'Raise funds for the new JonathanGluck and the Wayward Kind album!',
#  'The Spider and the Fly',
#  'Knock Down Drag Out',
#  'Day of the Dead Tyrion Lannister Calavera Vinyl Stickers',
#  'Harold VS The Horde',
#  'Camille Peruto - NEW ALBUM',
#  "Tye's Photographic Journey.",
#  'Ropw',
#  'Wax Stacks LP Record Crates',
#  'The JANIS JOPLIN Project (Canceled)',
#  'Throw Over Car Door Dent Protector',
#  'Tofu: Stylish T-Shirts that are Made by Freedom',
#  'American Confines vol 1: Cincinnati in 52',
#  'Good Company',
#  'Launch "Romeo and Juliet in Yiddish" in New York City',
#  'Chasing Blue at The Trans Theatre Festival',
#  'The Ultimate Custom Shark Rig',
#  'Dynamic Faces Match',
#  "Tugboat Collective's Inaugural Season",
#  'Geocaching Trading Cards - History Series II',
#  "The FUN n' EASY CookBook For Children's Well.....Fun Cooking",
#  'Space Trucker',
#  'High',
#  'Club Wick3d',
#  'Modern Handmade Ceramics: Paper & Clay',
#  'Join me in completing my first Solo Project CD!',
#  "Emotional Makayla: Mommy's Birthday Gift!",
#  "Ashley's Beauty Tool Organizer Kit",
#  'Alaska Bug Bites, LLC - Farmers Markets Launch',
#  'Quick Query - Relaunch!',
#  'Quick, The Clockwork Knight Volume #2',
#  'WrittenWitheArt',
#  'Uptown Juice Company: Local, cold-pressed goodness',
#  'Objecthood: A Story of an Imagined Economy (Canceled)',
#  'Strain Wars: Playing cards',
#  'Wood Floor Fundraiser',
#  'Water Purification System Using Solar Evacuated Tube',
#  'The Chameleon Chronicles: Colors of Fate',
#  'Once Were Ghosts - Ephemeral 7-Song EP',
#  'Via Chic–OneClutch™',
#  'Afraid So Galileo Album',
#  'Paterson Falls Film Festival',
#  'Thailand country side',
#  'Equinox: my first comic (genre: fantasy)',
#  'Student Operated Fabrication Lab',
#  'Nurse Mare Foals: Born to Die',
#  'Funky Grits - fast casual diner pairing music with the menu!',
#  'The Great Kentucky Goblin Spree',
#  "Help Put Community-Building Art in Austin's Patterson Park",
#  'Kingdoms of Erden: King of the Mountain',
#  'Made From Scratch',
#  'Pierced Hearts Tattoo Boutique Start Up',
#  'Pole Diversity: A Showcase of Acrobatic Dance (Part Two)',
#  'A New Omni-Wheel. A mechanical innovation created for robots',
#  'BrewStick ~ carboy ruler',
#  'Open Fiesta Arts Store dreaming big in San Antonio',
#  'Nutty Nations: Re-Imagining Learning Through Games',
#  'Night Terrors: Garden of Limbo',
#  'Greek4Fun',
#  "Hood's Up Brewery",
#  'Fooju Dance Collaborative',
#  'CHRIS CRITELLI RECORDS HIS DEBUT EP!',
#  'Sleeping in a Truck',
#  'LEGO Imagination Lab',
#  'Arkham Source Book',
#  'Finishing & Festival Funds - The Final Stage - short film',
#  'Lonely House Films: Adam Hope',
#  'Adult Colour Debut Album',
#  'Open A.I.R.',
#  'At Home in Maine: A Film Series About Homebirth and Midwives',
#  'The FUSIONproject',
#  'Digitizing My Family',
#  '"Progress" The Steampunk Series - Season 2',
#  'Winter Writing Residency',
#  'DOME Shades: Sunglasses for Big Heads',
#  'A Portrait a Day 365 Challenge',
#  'XPUMP | TURN ANY SOUND SOURCE INTO A HOME THEATER EXPERIENCE',
#  "Complete Paine's Skatepark",
#  'Westward #8',
#  'TIBA Putt: A personal approach to improve your putting',
#  'Ghost Herds: Rescuing horses and horse people in Kentucky',
#  "Gideon's Epic Forge",
#  'The Farmer, the Bean and the Holy Roast',
#  'A Jessica Rabbit Production',
#  'Belleflower - A Feature Film',
#  'MAB MINDZ AT SOUND SET 2014',
#  '"The Get Back" an adaptation of Wrong Becomes Me',
#  'The Bicycle Bus',
#  'Danger!  Extreme Lawn Darts (Canceled)',
#  'My 1st Cookbook (for children)',
#  'The Book of Maxwell',
#  'Glory of the Three Kingdoms - Guandu Core Set',
#  "It belongs to the world: Ackermann's Repository of Arts!",
#  'SEVEN DEVILS - Feature Film',
#  'Chill Puck - Keep your beverage colder, longer.',
#  'Heroes And Other Strangers at FringeNYC',
#  'Quadrato Retractable Knife - Make 100',
#  'Un Amour Oublie "a love forgotten"',
#  "In the Loop: A Resource Strategy Game for Tomorrow's Leaders",
#  'The Contractors - Create 3D Model: Prop Asset Model #1',
#  "Sasha's Fashion Show - Spectacle",
#  'Bass River Press',
#  'Betul Soykan Records Joaquin Turina Violin Works CD Project',
#  'Food truck for the world.',
#  'Publishing The Occupy Portraits',
#  'Daweyu Hills – Crop to Cup',
#  "Pimax: The World's First 8K VR Headset",
#  'i do it 4 oakland',
#  'Florida: A Broken Kingdom',
#  "Help start Jacksonville's FIRST Paint Your Own Pottery Store",
#  'Scar Tissue',
#  'I Am Pro-movement:',
#  'Peak View Brewing Company',
#  'Audience of Death (Canceled)',
#  'Finding Black Love: The Documentary',
#  '" The Patch, Organics "',
#  'Virtual Addiction Recovery Website & Phone App/ Saving life',
#  'Titanium Whiskey Glass - The EPIC Drinking Glass',
#  'WHAT CHILDREN DO - A Feature Length Comedy',
#  'College Spring Break Review',
#  'Tall Tales: An evening of dance with ChoreoJoey',
#  'Light Comes In',
#  'Rocky Horror Saved My Life - A Fan Documentary',
#  'CLEX - 4 in 1 Smart Device (Canceled)',
#  "Songs of the Damned Jake Brock's Latest Album.",
#  'Circa Vitae requests crowd fundage to record our full length album... TO VINYL!!!',
#  "Stiletto Red's New EP",
#  'Bucks County: the Movie',
#  'LazerShirts! Not Just Another Shirt',
#  'Country Christian album titled "I Believe"',
#  'Colors Do-it-Yourself Art Party',
#  'Wholesters- A new way to Whold your things!',
#  'Stamped',
#  'Ripple Analysis: Bringing Animation to Life',
#  "Croc2Pop - Where kids manage dad's digital addiction",
#  "Carolina's Hottest",
#  'TULIPS',
#  'Ignis Fatuus Comic Project',
#  'HoodRatz',
#  'Kingdom: The Space Exploration RPG',
#  'DotPen : Redefines drawing and writing for smart devices',
#  'Deluxe RPG "Handbrain" Screen',
#  'C R O S S T O W N  - help us finish our feature film',
#  'Spicing it Up at Whipped & Beaten Culinary Works',
#  'Grilling with Beer cookbook',
#  'The Womanhood Short Film Fundraiser',
#  'Sunrise Diaries',
#  'Me and my Tommy',
#  'Bromotion',
#  'FILM PROJECT:  A HISTORY OF COMING OUT',
#  'Savage Thunderscape!',
#  'THE MC TYPE: BAD TATTOOS VOL. 3',
#  'No Man Is An Island',
#  'Grandkids Record a Full-length Album!',
#  'FIREWATER',
#  'Annulus: Ring of Light',
#  'Gospel Jazz Independant Artist - CD Project',
#  'Ugly Cartoons (Poorly Drawn) for Miserable People!',
#  'The Daisy Dare Project (Canceled)',
#  'Occupy the Left Forum Zine',
#  'DANCING CLASSROOMS GRVA 2013',
#  'Daily Bread: Stories from Rural Greece',
#  'Monsters - A Short film by Christina Morris',
#  'Boating with Clyde: Adventures on the Puget Sound',
#  'Beyond the Victory recording their debut EP',
#  'DayStay',
#  'THE LEAGUE OF HONOR',
#  'making more bringpacks',
#  'Projecteo: The tiny Instagram projector.',
#  "Digital Aristocracy: A Commoner's Guide to Digital Riches",
#  "It's Time to Move On",
#  'Lazy Glamour: Eco-Underwear - soft, sustainable, and US-made',
#  'Saber Design Apparel',
#  'Capturing the Soul of a Town',
#  'StoryBox - What will you make today?',
#  'Cyberines #1',
#  'Poems For Apostates & tales of a young Scientologist',
#  'Senior Project Short Film: Home',
#  'Suburban Daze',
#  'Flyover Farm',
#  'Zero Dark Thirty: Watches that make a difference',
#  'Baby Names NOT to Name Your Newborn',
#  'Faithful: A Lesbian Mormon Story',
#  'LAZER EDGE Series eBike - Starting at $499!',
#  'American Dart Football - Where You can be the Quarterback!!',
#  'InteliShake - Smart sports drinks bottle + built-in storage',
#  'Face-To-Face: Short Film (Canceled)',
#  'Bailey the Golden Retriever Calendar',
#  'Paintings and Portraits! (Custom paintings)',
#  'The Spun Monkey Dyeworks and Lounge',
#  'The Living Puppets: Novel',
#  'Projects of Earth: And They Call Us MONSTERS A Story of Bias',
#  'Yemanja Caribbean Restaurant, Bar, and Hostel',
#  'Eucalyptus Wear - Environmental Clothing Company',
#  'Jazz Funeral For Coney Island',
#  'Self Illusion\'s "Best Friend/Worst Enemy" EP',
#  'Blak.Woman.Dynamik-ReBoRn',
#  'Cause Art Gallery',
#  'ThailandMike No.1, Portfolio, hiccup tour guide & Sketchbook',
#  'Midwest Side Stories',
#  'Pentimento a documentary about Rene Gimpel',
#  'Mike Moreno Group - Fall 2011 Release',
#  'SANSIN_Band EP',
#  'Tales from Sheepland: from the imagination of a child',
#  'The Kindness of Strangers',
#  "Maybe It's Poison",
#  'Smart Dive Buddy: Smartphone Dive Camera & Computer',
#  'iPhone Skin Made From Real Apple Wood',
#  "GoalZidia | Let's Reach Our Goals Together",
#  'Mongol Art World Tour _ Save The Art',
#  'My Darling June',
#  'Blacklivesmatter Series',
#  'Sorensen Glass Studio',
#  'FREE SUPERCOMPUTER',
#  'Kings & Astronauts Documentary',
#  '"MUSIC OVER FAME" (NO DIVA DJS) T-Shirt',
#  'GLAMAZON: Publishing Campaign! (Canceled)',
#  'æmp:dance / amiti perry + company',
#  'Flutter & Flow Knitting Book',
#  'Sci-Fi Janitors VS the Redbull Soapbox Race',
#  'Redemption',
#  'Course: Make a Stunning Fantasy RPG with GameMaker Studio',
#  'Secret Behavior Magazine',
#  'Michale Graves “Vagabond Acoustic” Extremely Limited Edition',
#  'Odyssey Skateboards Launch',
#  'PoolPooj',
#  "Help Momma Root's Bake Shop Make The Big Move!",
#  'Shoot For Thrill or Shoot To Kill? Political Sculpture',
#  'The Structure',
#  'Money Shot',
#  'Vagabond: The Search for My Homeless Father',
#  'Earthreads...the Fabric of the Future',
#  'Amateur Prose: A book of poetry, stories and original art.',
#  'Little Boy Wonder - A Short Film',
#  'JUDGED...The Irreverent Party Game',
#  'PHANTOM-LIMBED: A Romantic Comedy',
#  "The Comfy - The Blanket...That's A Sweatshirt!!",
#  "The World's First Genuine, Intuitively-controlled Skateboard",
#  'Defenders of the Realm: Minions',
#  'Matt Whistler The movie - Feature Film',
#  'The Undoing Trilogy',
#  'R.A.D. (Canceled)',
#  'The Guardians of Salus: Book #1 in the Halix series',
#  'Blakes Burgers',
#  'Build a traditional tipi.',
#  'The Legend of White Woman Creek',
#  'Rock The Audition-In Concert/Sheri Sanders',
#  '"Fragile" Stephanie Mathias\' First EP!',
#  'Second Scene Culture City Project',
#  'Small Footprints (Canceled)',
#  'GO FAR: The Christopher Rush Story (2)',
#  'Esquilo: Simple IoT Development - WiFi + Web IDE + Cloud',
#  'T-Bone & the Cherry Hogs',
#  'Random Table Wiki',
#  'Natural face, feet, and body scrubs',
#  'LDS Home Teaching App (Visiting Teaching Too)',
#  'Fritz: A Robotic Puppet',
#  'Casper & The Bad Spirits LP Funding',
#  'WORLD FAIR',
#  'Campbell Glassworks Co.',
#  'Airlock bike helmet',
#  'THE WOODS',
#  'A Better Morrissey Birthday Mix',
#  'A Ride for Suicide 2015',
#  'Suzanne Iris Mayer Solo Art Show (Canceled)',
#  'Tara Normal',
#  'Photoshop for illustrators and designers.',
#  'Profound Fatigue, produced by Flying Deer Theater (revised)',
#  'Dear Atlantas',
#  'Painting an entire favela in Rio de Janeiro',
#  'OPEN The TANK',
#  'Reed - Bringing Tablet Reading Up to Speed',
#  'Flags of the world',
#  'Mover Kit: get kids moving, building & coding',
#  'The VolksDangler: Hack your pockets',
#  'the mailboxes forthcoming album!',
#  'Rocket Ranger Reloaded',
#  'Write my Estimate - have your estimate written anywhere!',
#  'PortsCenter',
#  'So You Like the Neighborhood',
#  'SparkLab: the educational build-mobile!',
#  'Karma Gets A Face Lift!',
#  "Bull & Dragon's Pop-Up Restaurant Project",
#  'MAY THE TORQUE BE WITH YOU',
#  'Stage one & Stage two Music theatre',
#  'Phochron XA Film Camera Shutter Speed Tester',
#  'Vivian the Dog Moves to Brooklyn',
#  'Darkghost Assignments: The Book Brothers',
#  "This Mick's Life",
#  'Free soap from starting soap maker!',
#  'Nice Set of Shells~~ Handmade Seashell Jewelry',
#  'Shattered & Restored',
#  'Barry County Milk',
#  'The Giant Communist',
#  'Surf Right - A Documentary Inspired by Cold Water Surfers',
#  'Can You Survive: TREASURE ISLAND (Choose Your Path)',
#  'Talega Holiday: Annual Halloween Light Show!',
#  'Help me publish my picture (kids) books!',
#  "Moon's Eye View - Save The World",
#  'How safe is your food, makeup, and household products?',
#  'Geek Seekers',
#  'Nabil & Karim | Anise K ~ Bicentenary Album',
#  'Destroy All Slackers - An Animated Feature Film',
#  'Sheet Musica Project (Canceled)',
#  'Seeker Aerial Video Drone',
#  'Quikceipt! Paperless Solutions',
#  'Mini Army custom minifigures (Canceled)',
#  'Splendid Entities: The Catalog Project',
#  "Champion of Children vol. 1: I'm Known as the Champ Fund",
#  "The Ale House String Band's Debut Album",
#  "New Cornell Hurd Band CD...Great new songs you'll love!",
#  'DodecaheDRONE: An RPG of post-apocalyptic Robots & d12s',
#  'FOLLOW ME - HELP US GET BARNEY',
#  'Da-dome Roller Skating Rink of Brooklyn New York',
#  'Tankwork: Cooperative Tank Action',
#  'Winter in Mind EP Funding',
#  '12 Day Commision Spree #1! Get some custom hand-drawn art!',
#  'Charlene Kaye makes a new record - "Animal Love"',
#  'Top Chefs Opening Shakewell Bar & Kitchen!',
#  'The Lonely Himalayas',
#  "Phrenic's Interactive Comic & Alternate Reality Game",
#  'Carnival Arts Exhibit at Miami International Airport',
#  'The Dead of Night',
#  'WazUpio',
#  'Daggermond',
#  'Choose Your Fate - The film that puts YOU in charge',
#  'Lock It Jeans',
#  'Dos Pueblos Tecnicos',
#  'GEEKHOLDER - Holds phone/tablet over laptop screen',
#  'Maze Slime',
#  'Long Range MURS Band GPS Tracker & Smartphone Communicator',
#  'Local Edition Book, "The Mortgage Game".  Print On Demand',
#  'CAKEHOUSE :Layer Studios Comics Zine.',
#  'CLEAN READS Monthly Book Box Subscription Launch',
#  '1of10: T-Shirt To Protest Trump / Putin Connection',
#  'DOCTOR WHO: THE MENACE OF FOONF',
#  "Bird's Eye View 1892 Map of Atlanta - 1000 Piece Puzzle",
#  'The Prelude to the Conversation',
#  'Art Lovers Place',
#  'Bona Dea Gluten Free Goodness',
#  'How I Got Beat-Up By The FBI When I Was Four Years Old',
#  'Pony Death Ride is making an album!',
#  'Help Kasper release his newest mixtape! (Canceled)',
#  'Love Animals - Debut EP Project',
#  'The Unknown: Arizona',
#  'Bridge of Sighs Short Film -- Part 2',
#  'Legendary Steamboat Springs Band records an album-- after 30 years!',
#  'Luxury Timepiece System: a Minimal Everyday Watch System',
#  'Maree v. State: Not Just A Documentary',
#  'Girdy! A Webcomic',
#  'Da Stooges in WipeOut by the Surfaris',
#  'The Lobster Art Project',
#  'QUARTZ Bottle - Water Purification in a Self-Cleaning Bottle',
#  'The Creative MiND Challenge (Canceled)',
#  'Following Racine: The East Africa Safari Rally',
#  'Sky Lounge: A Visual EP',
#  'AcneDust™ Organic Acne Treatment -Acne Dust Sleep Powder',
#  'The Legendary Cobo',
#  'Storm Hollow: Call to Adventure',
#  'Philip & Brittany Burton - NEW ALBUM - Nothing to Fear',
#  'Mason-ry Silicone Koozie',
#  'Shirts for the East Idaho Aquarium',
#  'PS Pi',
#  'New LP Release by The Shape Of The Earth',
#  'RinseKit: The Revolutionary Portable Shower',
#  'Singularity',
#  'TALUVA: DELUXE VERSION',
#  'Calvin Thomas: Making the "October Sky" Album!',
#  'Wilmer Wilson IV Summer Art Residency at NLS',
#  'Gladys Sings',
#  'The 2012 Lake George Music Festival',
#  'Seeking Shelter Vol 3: Rescue Animals Ho!',
#  "The Fail Safe Project's First Full Length Album",
#  'Through Your Door - Feature Film Finishing Funds',
#  'Decorative Oxygen Tank Bags by AmariJade, Inc.',
#  'fig Films Presents: Bear Down (Canceled)',
#  'Commit Suicide',
#  'The Scarf Cuff',
#  'Behold The Uprising EP',
#  'We Did It For You! - a historical musical (Canceled)',
#  'JOHNNY STRANGE',
#  'Legendary Warriors Productions',
#  'A Statue of the "DOC" to the U.S.Marines, The Corpsman!',
#  'StageCoach Mary',
#  'Knot App',
#  'PowerBark-"Meal on the Run for the Dog on the Go"',
#  'Tenacious Exclusive Scott Tolleson Uncle Argh NOIR Mini Qee',
#  'Centennial Armenian Genocide T-Shirt',
#  'mini flashlights and fire starters',
#  '"It\'s bigger on the inside"',
#  'Lololi',
#  'Jordon Bould Butcher Blocks',
#  'WE ARE NOT ALONE',
#  'SOMASOL Vegan Balms Production Space (Canceled)',
#  "Hackchain - The World's First Wearable Wifi Jammer",
#  'SoMo: The Mixtape',
#  'The Little Women Graphic Novel Project',
#  'Joy Ike is Recording Her 3rd Full-Length Album! Lets Do It!',
#  'Lotus earring',
#  'The Adults',
#  'Bohemian Book Project',
#  "A Tenor's Journey To The German Lands",
#  'Vanilley Bean Treats! For life\'s "sweet" moments!',
#  'Wheeling, Careening, and Wandering through the EMP',
#  'Fireball Newsflash Crosswords 2015-16',
#  'Kung Fu Bellydance Masters ????????',
#  'ONE WORLD - ONE YEAR',
#  'Living Coaster - a beverage coaster that grows plants!',
#  'Chop Sooey Charm Pins',
#  'The Wheelhouse: A Farm to Table Restaurant in St Joseph IL',
#  'Galaxy of Trian: New Order',
#  'Air.Air! ~ Portable Air Quality Detector',
#  'CONDUIT Sports - Dynamic Bone Conducting Headphones',
#  'Artlysium Presents "The Broken World Project" by Bryan Hill',
#  'Urban Diverse Podcast',
#  'ONE',
#  'Tableau Vivant of The Delirium Constructions - GLOBAL TOUR',
#  "Seth's Pineapple Mango Salsa",
#  'One Day at a Time: 365 Days of Photographs',
#  'Free World Brand Clothing Co.',
#  '"Planet Hell" - Post-Apocalyptic Web Series',
#  'Little Falcon Needs Your Help!',
#  'Customizable 3D Printed Miniatures',
#  'Short Defender ©',
#  'HEYA Toothbrush Holder...simple & clean, keep bacteria away!',
#  'Imminent',
#  'She Had Love On Her Tongue & Death In Her Eye',
#  'Pocket Parking Meter',
#  'Cat Cafe Mad: Coffee Shop Remodel & Expansion & Real Food',
#  'Unconditional Hope -  A Survivors Story.',
#  'Finishing The Amish Appeal',
#  'Fake Logo is Making Real Music (Canceled)',
#  'Sports And The City',
#  'Vyu360™ 4K ProCam',
#  'The Justifier',
#  'EZ Master: Double Boiler Attachment for Stand Mixer',
#  'Shakespeare!! To fund or not to fund, that is the Question?',
#  "The Monkey's Other Paw",
#  'Charlie vs Goliath',
#  'Wireless Touchpad for Console Gaming Controllers (Canceled)',
#  'New Madysin Hatter EP, To Be Titled "Pretty Little Fool"',
#  'Durango Falls TV Show',
#  '"The Coach" The Life and Times of Shawn Tompkins',
#  'Life Online',
#  'Kingdom: The Angelic War Card Game',
#  'April Alayne Studio.',
#  'ULTRA WAY COOL TEACHING PUPPETS',
#  'Chain Mail Creations',
#  '3D Film - The Perfect Divorce',
#  'An Above Average Grilled Cheese',
#  "A Big Dream of a Little Man - Alex Oddman's Debute Album",
#  'Supplicant - The Age of Dissidence',
#  'Sandia Creek Sustainable Farms & Community Support Project',
#  "Alé Garza's H.A.R.D.CORE!!!",
#  'Kind Minds & Wise Souls... Launch Our Next Collection!!!',
#  'Bring the Seattle Geekly podcast back!',
#  'La Feria Concreta: A Documentary Film Installation',
#  'Debut Original Album by Mindy Stratton',
#  'Night_Rider',
#  'Xybears The Last Heroes',
#  'ARCHIVE The WarHood Odyssey',
#  'VAUDEZILLA! Chicago Burlesque Coloring Book by Matt Hansel',
#  'Homestyle: Video Installation at Delicious Spectacle',
#  '4 Color Press for 5th Street Garment Company',
#  'Maltese Brewing Company',
#  'Hollow',
#  'GrandLo Café',
#  'Dionysius Games - Indy Games for everyone.',
#  'Desktop CNC Compact Mill & Drill (Canceled)',
#  'EZ-CARSEAT making child car seats EZ (Canceled)',
#  'Markus Mann Music - CD production and Tour',
#  'Tropical Bat Houses',
#  'Wade in the Water Gallery',
#  'Woodland Banners Poetry Walk',
#  "No Soul To Take's 2nd EP Record",
#  '"Home is Where The Jug Is" Decal, T-shirt, Trophy & Tailgate',
#  'Battle for Orion 2',
#  'Pretty the Ugly at AWP',
#  'HOMEBOUND the film...Transforming the image of Latinos.',
#  'Nepenthe: A Short Film',
#  '"Jesus and the Homeless Woman" From clay to Bronze',
#  'English for Immigrant Children - English as a 2nd Language',
#  'Audio the Heroin-Chic Cyber-Doll',
#  'Self Produce My Debut Album',
#  'The Bizarre Case of the Globular Gullet',
#  'Earth Wall II - Rammed Earth Sculpture',
#  'Two Boys and a Bow Tie Tour',
#  '"Inches" - A Short Film',
#  'TeslaTronix- Tesla Power For The Masses',
#  'Lightbook (Canceled)',
#  'Wood Gifts That Make a personal Memory',
#  'Impaycent Minds',
#  'Pastor Damien Season One',
#  'Speculative Relationships: A Sci-fi Romance Comics Anthology',
#  'Veteran Art by David Geig',
#  'Marketplace for Crowdfunded Products',
#  'Note to Self',
#  'Maria Sweet sings!',
#  'Aurora - Chronicles of a Hero',
#  'Pretty Girls, The movie (Canceled)',
#  "AJ'S HANDMADE STYLES",
#  'PALADIN: Warriors of Charlemagne',
#  "Jessica's Jewelry",
#  'The Creative Community',
#  'Green Light Radio broadcasts the Arise Festival 2014',
#  "Poetry Isn't Safe: a new Best Reading Ever Film",
#  '1 Man, 10 Days, 100+ Canvases',
#  '(BT) Block Tower',
#  'Versa-Tool',
#  'DreamAfrica',
#  'Failure, You Are Not My Jacket',
#  'A R&B Project in need of pledges (Canceled)',
#  'Imagine You Could Build Anything',
#  'Dayz To Come + You = New Worship Project',
#  'Healthy, Sustainable Clothing',
#  'New York Travel & Sightseeing for All - A Video Blog',
#  'E Coin Mining and Rig-Building Workshop',
#  'Loquat "We Could Be Arsonists" Short Film/Music Video',
#  "Unique Collage's",
#  'Corey’s Coffee Bar',
#  'Inhale Sunrises.',
#  'Ghetto Love written by Weedie',
#  'Ping 2: Attack of the Spheres / Wii U, PS3, Steam',
#  'Loud Bicycle: Car horn for your bike',
#  "VINCE DURDEN: World's Most Eco-Friendly Backpack",
#  '2000 Miles',
#  'Black Mint Playing Cards',
#  'The Holiday Experience 2014 - A Jazzy Christmas Celebration',
#  'Renwick Ally Album by Ryan Angell aka Andrew Juco',
#  'The Amphibious Red Couch',
#  'Rabbitwild - A Shelter in the Wilderness',
#  'Leah Stein Dance Company 10th Anniversary Concert',
#  'Upcycled planters',
#  'Youth Education TV Talk Show',
#  'Mango, Pineapple & Habanero Toe Curling HOT Lava Sauce',
#  'Epic Backpacking Dynasty: The Global Millennial Revolution',
#  'Fantuckfastic Onesies',
#  'iWISH: Sigil Magic',
#  'Orbs CCG, the asynchronous digital collectible card game!',
#  '"Sawyer The Dinosaur" Children\'s Book',
#  "The Magician's Cat, Print edition of the eBook!",
#  'The Berwyn Project EP by The MC Type & thewoods',
#  'IVIOU The future of buying and selling online',
#  'Rustic Reclaimed Furniture 100% hand made',
#  'The Lonesome Days 1st Studio Album!',
#  'League of Legends Cosplay',
#  'Seeing Swiss: Pictures, People, and a World of Engineering',
#  'Love. Guts. High School.',
#  'CAFE GANGSTER',
#  'Rivers Monroe Fall Tour 2016',
#  'Golf Alpha Yankee: An LGBT Human Rights Documentary',
#  'Colombian art gallery in LA: The Magic Realism strikes back!',
#  "Can't Turn Back Now",
#  'DIY BOXCAT by Rato Kim - The Vinyl Art Toy Platform',
#  'Ten Animal Masks in 10 Weeks',
#  'A Dancer Descended Mount Kenya - A Memoir',
#  'Streetest Miami - Support Our New Sports Apparel Line',
#  'Press Start Bar',
#  'T-Shirt Design Startup',
#  'Zisil',
#  'Faceless Neil',
#  "StarBird lands on Earth with the debut album There's No Time",
#  'Bryan Wilton, From Print to Audio',
#  'Downtown Murals',
#  'Zombie USB Keychain (Zed 1.0)',
#  'Skullgarden Linocut Print Project',
#  'Soundtrack: The Story of the DJ',
#  'Give in to Sweet Surrender',
#  'The Alaina Blair CD-Tour Project',
#  'Cemetery Angels - A Photographic Book',
#  "Sledge Leather's reply to(insert large-ass metal label here)",
#  'KENSAKU SHINOHARA : AT MANA TO SPRING 2014',
#  'Help me exhibit at an art show by Geordanna the Artist',
#  'ExoSkeleton Assault Squad and Hura Technocracy - 15mm Sci-Fi',
#  'MoAR - An Online Multiplayer Fighting Game',
#  'Esperanza: A Gang Intervention (Photo Documentary)',
#  'How To Create A Liberal America',
#  'Cooking With Fire, The Disaster Cookbook',
#  'Paragon - Short Film (Canceled)',
#  '"Violet Tendencies" (starring Mindy Cohn) on DVD',
#  'Disgruntled Decks: The Original Card Game For Veterans.',
#  'We Come From The Sea - An Ambitious Short Film',
#  'Sol McNally Photography',
#  '45 LED Packlight - Lets You Bend Light Where You Need It',
#  'On Home Ground',
#  'Pixel Press: Draw Your Own Video Game',
#  'Sexy Action Accounting Myths, a short film',
#  'Moment: Make Your iPhone 7 A Better Camera',
#  'Poetry Will Never Be The Same',
#  'Post Election Student Voices of Hope & Resistance',
#  'Ion: A Music Detecting Mood Light with Bluetooth Low Energy',
#  "Bringing Patrizi's Back: A family food truck experience",
#  'Musical Help for Trouble with Numbers (one of many)',
#  'Fused By Defiance Album 2015',
#  'Rolling : a real journey  (Canceled)',
#  'Go Mobile Drool Central',
#  'Awfully Sudden-The Album',
#  "Coon's Age Volume One",
#  'Let Us Make Man (Canceled)',
#  'Might As Well Live: Dorothy Parker Does Hollywood Fringe',
#  'Traditional Astrophotography: A window to Cygnus',
#  'Hole in the Wall - Hector Records His Debut Studio Album!',
#  'Lighten Up',
#  'Surrender to Spirit Creative Writing Project - Phase 1',
#  'The Secret Tomato Project',
#  'XSTINK',
#  'Opening an online-gallery for great Dinosaur Art and Artists',
#  'The Art of Mitch Foust 2017 Yearbook',
#  'Bring Victorian to Life.',
#  "Chat's Choice Gaming",
#  'Thank You Letters from Krys',
#  'MargOH! in "What makes a legend drink more? London Style"',
#  'OPUNTIA',
#  'Debut Hip-Hop Album by MikelWJ',
#  'Temple Flower | Vibrant Activewear and Yoga Apparel',
#  'Scorned starring American Idol alum & 2x Grammy nominee Chip',
#  'The "Here I AM\' Project',
#  'A Weekly Video Series',
#  'Bike Pouch',
#  'GLOBAL INTERSECTION 13: A World of Materials and Methods',
#  'Zombie T-Shirts & Hoodies',
#  'Moustache Bow Tie Project for Mo Bros & Mo Sistas',
#  'My first official music video for my single "Forever"',
#  "Personalized Children's Book (Canceled)",
#  'Our Bible App',
#  'Garment Collective: Ethically sourced. Redemptively Made.',
#  'In The Beginning by Mark Barnes',
#  'The Challis Effect: Your Heart Was Built On A Graveyard....',
#  'A:LOG',
#  'Maui to Maine 2017 | CLAYBOURNE TOUR',
#  'Tiddly Trailer Bar Co.',
#  'The Dihydrogen Monoxide Conspiracy',
#  '3D survival Kit',
#  'Tons Of Music For A Buck!!!',
#  'Adoree - European Promo Tour (Summer 2011)',
#  'Read The Bible in 1 Year Card System',
#  'Rob Wiley Custom Leatherwork',
#  'Entropy: Lovecraftian horror meets sci-fy',
#  'N3ON LOVE official launch',
#  'Famous Paintings - a tribute to another art form (Canceled)',
#  'LittleRP - Affordable Flexible Open 3D Resin Printer',
#  'Fallen Guardian Angels Film Project',
#  'a hilarious film called "mooo"',
#  'Hi! Please help me publish "The Wizard\'s Legacy"!',
#  'Bondurant Brothers Distillery',
#  'My Summer as a Goth 2016 Finishing Funds',
#  'Duo: A DIY twin lens reflex camera for instant film',
#  'Pursu. Passion. Career.',
#  'Crazy Train',
#  'MY LIFE AS I SEE IT',
#  'PongCaddie - Save Your Balls With Our Beer Pong Nets',
#  "Julia Fanning's Debut EP",
#  'Z Day by Lena Pendleton',
#  'The road to Italy!',
#  'Immersive Cinema',
#  'BBQ Dragon - The Barbecue & Fire Supercharger!',
#  'Dineamics',
#  'The UNEARTHING',
#  'UNCLE SAMta – FINAL HOURS',
#  'We Came To Sweat',
#  'Finish El Toro The Tot Food Trailer!!',
#  'MadJacks | Ski Pain-Free | Walk Normally | Affordably',
#  'Phil KIng and Leeland',
#  'Elbows & Knees: the "Crippled By a Crush" EP',
#  'Broadway Comes To Denver: Scholarship fund',
#  'Bedroom Behavior Lingerie',
#  "Hollander & Lexer F/W13 Women's Clothing Project (Canceled)",
#  "My Parka | World's Most Elegant Authentic & Functional Parka",
#  'For Love of Libya',
#  'Amazing Tales of The Wasted Lands inaugural issue pre-sale!',
#  'GEEX Season One!',
#  'The Old Soul of a Lion',
#  'Sleep-A-Board',
#  'Kevin Woody - First Solo Album',
#  "Norman Einstein's NORMANTHOLOGY",
#  'PRESIDENT OF THE UNITED STATES (Suspended)',
#  'Please Donate Money For My First Music Video Shooting in September',
#  'Kronos at the Pino Family Ranch',
#  'Bicycle protection on the move. (Canceled)',
#  'Low Shoulders - A Short Film',
#  'The Endless Whispers Cycle Featurettes',
#  "Dexter's Etsy Shop Expansion",
#  'Inflatable Jake band T-shirts',
#  'Artisan Vinegar',
#  'Saga of the Splintered Realm',
#  'Make COOLRUNNINGS first physical release a reality.',
#  '51st Studios Unplugged: Wood Headphones featuring Bluetooth',
#  'Will the Film',
#  'Edgar Wallace Jr. (Gets Saxy in the studio for new C.D.)',
#  'Cirsova 2017 (#s 5 & 6): Lovecraft, Swords and Space Ships!',
#  'LEGO My Chess Set',
#  'Feeding Fingers - Their first double album',
#  'Telemetry Webisodes',
#  'Songs Without Words',
#  "Chris Custom Built PC's",
#  'Code name: Interstellar (Canceled)',
#  'Make a Record with Ben Cyllus - be a part of the new project',
#  'STILL MOTION presents "Moments Defined" NYC',
#  'Letters from Basic Training',
#  'A Major Factor',
#  'Affordable Computer Controlled Quilting System Add-On',
#  'The ODYSSEY by Homer - Amazing Youth Actors, Giant Puppets!',
#  'NAMM Marketing -keeping up with the big dogs',
#  'Debut EP Album Promotion',
#  "Doodle: The Creatively Interactive Children's Book.",
#  'The Green Lamp Prototype (Canceled)',
#  'The Conservative Theatre Festival: Columbus, OH, 1/7/17',
#  'Spread the Love',
#  'How To Run Fast',
#  'Fashion wear for Sweater Weather!100% Wool Hoodie & Sweaters',
#  'SHRED. Pro Rider Snowboard game.',
#  'The Riddle of the Sphinx',
#  'Weekend Love',
#  "Los Angeles Women's Theatre Festival - 24th Anniversary!",
#  'Daniel: an Ordinary Tragedy: a new musical',
#  'THE GENESIS COLLECTION',
#  'Tail Feather Belts (Canceled)',
#  'The Journey West  ~ a novel based on a true story (Canceled)',
#  'North State Grocery Documentary (Canceled)',
#  'Covalence: A Molecule Building Game',
#  "Professor Vogel's Alternative History Machine I&A Issue III",
#  'Monadnock Gymnastics',
#  'The Purveyor (Canceled)',
#  'Cinema Verde',
#  'The Dousing Sauce Story',
#  "The King's Guild",
#  'Masters of the Tooniverse Podcast (Suspended)',
#  'The Nostalgic Restoration of Your Youth',
#  '"Beast of Spearpointe" book 1 of 10 New Epic Fantasy Series',
#  'Napa Valley Private Label Wine',
#  'Humans Wanted: A SF Anthology',
#  'Ian Mahan new album "Little Moments"',
#  'GBS Detroit Presents Daniel Harrison and the $2 Highway',
#  'A pot of coffee',
#  'Pet Beds',
#  'Radiate Portable Campfire- Tailgate Ready- Made in the USA',
#  'Paprika: The Short Film',
#  'Life & Career Changing Dream Camera Goal!',
#  'DSW74NEWS LIVE BROADCASTING',
#  'Dead Burger by Abomination Films!',
#  '"Star in a movie like \'Entourage\'" The 420 Crew (Canceled)',
#  'Nina Jo Smith’s PEOPLE PLACES & SINGS CD',
#  "GRITS on wheels in Los Angeles! Ya'll come an get it!",
#  'Hotdog Yogatote',
#  'Travel Far: A... Guide to the Out-of-Body Experience...',
#  'Who is Nellie Bly?',
#  'Get It On The Shelf!',
#  "Nahla's Oasis",
#  'Help Us Record Our Debut EP "Mayday"',
#  'tipstir',
#  'ChileFornia- An anecdotal view of identity, immigration & diversity',
#  '"Revolutionary Love"',
#  'Colorful & Challenging Jigsaw Puzzles',
#  'The Creative Side - A Photography Webseries',
#  '"Projection" a short film',
#  'The 1st Motion Tracking DIY Smart Home Security Camera',
#  'Veterans',
#  'MY VERY FIRST KICKSTARTER',
#  'This Song Is About You',
#  'Telemedicine wound care provider locator',
#  'Knock On Wood',
#  'TeleSound: The Sound Messenger',
#  'Pointe Blank T-Shirt Refresh',
#  'My Journey With God-Inspirational book on faith, forgiveness',
#  'The GoShelf™ - corner shelf self installation system',
#  'Trash Talk Death Match',
#  'A Postcard From Lily Dale',
#  '"Written and Directed by Elaine May" T-Shirts',
#  'Kevin Dillard solo cd "Symptoms of The Human Condition"',
#  "Lucky's",
#  'Project Penny',
#  "Lilah's Guide to Hoyle",
#  'US Army Navy Marines Air Force - Special Challenge Coin',
#  'Multi-function kids chair with a "one for one" concept.',
#  'Ximphonic Versus',
#  'Mottainai',
#  'Model T Tintypes',
#  "GROTTO: an artist's book",
#  'Sticky Boo Yum Yum | All Things Marshmallow',
#  'Music & Song Production for Athena Creese Recording Artist',
#  "Our Own End's New EP!!",
#  'The sexiest lingerie greeting cards ever...',
#  'Opal Zine - Issue 03.',
#  'Pure Me',
#  'Para Doc Film',
#  'Back in the Soviet Bloc - a 6-part tv series',
#  'Fighting Fear & Doing Discipline',
#  'eyeForce VR Headset, no black parts, 210° field of view',
#  'Shell-Shock',
#  'Tactile Turn Mover & Shaker Pens - New Materials',
#  'Record Original Tunes at the Wood & Stone Studio',
#  'Raggedy Edge: Deja Vu',
#  'Launch Alligator Bites and Open Wide to Possibility!',
#  'Wild Cards- Playing Card Games',
#  "Dread: Shoot 'Em Up | For Desktop, Mobile, & Oculus Rift",
#  'Funding a Veterans second chance',
#  'BANQUETTE',
#  'Comicverse: Under Fire!',
#  'Pirates Lagoon',
#  'GAME TIME: TIC-TOCK TIC-TOCK ANTHOLOGY',
#  "'One Native'... Social Architecture for Social Concerns",
#  'CHF Woodcrafts Handcrafted Art',
#  'PHOENIX FearCON 5 International Independent Horror Film Fest',
#  'Take HOTWIRE Action Romantic Comedy to $11,000',
#  'The Space Between Worlds: Auctumnalis',
#  'Solecon Buy.Sell.Trade',
#  'Military Wallet by Bench Built',
#  'Picture Their Faces Photo Booth: Bringing smiles to all!',
#  'Portakali "Discussions in the Dark"',
#  'ssk (Canceled)',
#  'Negative Space',
#  'The Sleep Sensei - Fall Asleep Faster Without Medication',
#  'The Cage (SENIOR THESIS PROJECT) (Canceled)',
#  'Double-Sided PLUSH Terrain Mats by Cigar Box Battle Mats',
#  'The Firebird Band New Album (www.firebirdband.com)',
#  'hello (Canceled)',
#  'Linkme: The Ultimate Collaborative Platform',
#  'Decisions',
#  'Born For This',
#  'New Music Video!',
#  'Cable Label',
#  'Help support for full length recording',
#  'Creative coping',
#  'Luxurious handcrafted candles made from 100% soy wax',
#  'Murder for Xmas 2014: "Gray Shadows Under a Harvest Moon"',
#  'Ethically conscious clothes that will outlast you.',
#  'Backslash About Presents "EPISODE 13"',
#  'The Shepherd',
#  'Hermagedon - An epic old school fighting game',
#  'Official CITY SLEEPS Unreleased Album Kickstarter!',
#  '"Witchcraft Blue" (A Burlesque Documentary)',
#  "'FLIP' the Bird & Cat Game (Canceled)",
#  'Ikuzi Dolls - Beautiful Black Dolls (Canceled)',
#  'Orio Isamu - A humorous manga tale of 1st time intimacy',
#  'STEVERA Belt, Metal-free, Bulge-free, Pinch-free, Unisex',
#  'The Witch',
#  'SPARE ME 5-1 Automotive Rescue Tool',
#  'The Family Soup Bowl',
#  'I AM SOUL RAP (Canceled)',
#  'Follow my Lied: Fund an Artist',
#  'BaggaBox',
#  "Jazz Legend John Danser's New Band",
#  'Rosaline Fashions: Eco-Friendly line of Accessories, Jewelry & Custom Fashion',
#  'The Quiet Pictures Experiment',
#  'Moon Far Ocean Deep',
#  'WarmUp: A High-Protein Coffee',
#  'Gold Digger (Canceled)',
#  'SIGNOOS - Free EDU Series for Deaf Schools around the world.',
#  'Albumen Portraits',
#  'Innervation (short film)',
#  'The Melody of Choice',
#  'BEING SPECIAL: A Differently-Abled Documentary & Book...',
#  'Sea of Glass, by Warbler (Canceled)',
#  'Arrangement - A Short Film',
#  'Angie Pittman to Vienna for danceWEB!',
#  ...]
